# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("NYPD_Complaint_Data_Historic.csv")
# Out:
# C:\Users\com\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (20,23,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head().T
# Out:
#                                                 0  \
# CMPLNT_NUM                              992676316
# CMPLNT_FR_DT                           12/31/2018
# CMPLNT_FR_TM                              9:00:00
# CMPLNT_TO_DT                           12/31/2018
# CMPLNT_TO_TM                              9:32:00
# ADDR_PCT_CD                                     6
# RPT_DT                                 12/31/2018
# KY_CD                                         341
# OFNS_DESC                           PETIT LARCENY
# PD_CD                                         313
# PD_DESC            LARCENY,PETIT BY FALSE PROMISE
# CRM_ATPT_CPTD_CD                        COMPLETED
# LAW_CAT_CD                            MISDEMEANOR
# BORO_NM                                 MANHATTAN
# LOC_OF_OCCUR_DESC                          INSIDE
# PREM_TYP_DESC              RESIDENCE - APT. HOUSE
# JURIS_DESC                       N.Y. POLICE DEPT
# JURISDICTION_CODE                               0
# ...

# %%
df = df.drop(columns=['CMPLNT_NUM', 'ADDR_PCT_CD', 'BORO_NM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'CMPLNT_TO_DT', 'CMPLNT_TO_TM', \
                      'CRM_ATPT_CPTD_CD', 'HADEVELOPT', 'HOUSING_PSA', 'JURISDICTION_CODE', 'JURIS_DESC', 'PARKS_NM', \
                      'PATROL_BORO', 'PD_CD', 'PD_DESC', 'RPT_DT', 'STATION_NAME', 'TRANSIT_DISTRICT', 'X_COORD_CD', \
                      'Y_COORD_CD', 'Latitude', 'Longitude', 'Lat_Lon'])
df.head().T
# Out:
#                                         0                           1  \
# KY_CD                                 341                         578
# OFNS_DESC                   PETIT LARCENY               HARRASSMENT 2
# LAW_CAT_CD                    MISDEMEANOR                   VIOLATION
# LOC_OF_OCCUR_DESC                  INSIDE                      INSIDE
# PREM_TYP_DESC      RESIDENCE - APT. HOUSE  RESIDENCE - PUBLIC HOUSING
# SUSP_AGE_GROUP                    UNKNOWN                     UNKNOWN
# SUSP_RACE                         UNKNOWN                       BLACK
# SUSP_SEX                                U                           U
# VIC_AGE_GROUP                       45-64                       25-44
# VIC_RACE                            WHITE                       BLACK
# VIC_SEX                                 F                           F
#
#                                 2                               3  \
# ...

# %%
for column in df.columns:
    print(column + ":" + np.unique(df[column].values))
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-15-137ab2794a65> in <module>
#       1 for column in df.columns:
# ----> 2     print(column + ":" + np.unique(df[column].values))
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('<U21'), dtype('<U21')) -> dtype('<U21')
